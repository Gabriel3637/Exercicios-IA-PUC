# %%
import setuptools
import sys

print(setuptools.__version__)
print("distutils" in sys.modules)

try:
    import distutils
    print("✅ distutils disponível:", distutils.__file__)
except ImportError as e:
    print("❌ distutils não está disponível:", e)
# Out:
# 80.9.0
# True
# ✅ distutils disponível: /home/gabriel/Documentos/Projetos_git/Exercicios-IA-PUC/.venv/lib/python3.12/site-packages/setuptools/_distutils/__init__.py
