# %%
import Neuronio as nr
import RedeNeural as RN
import numpy as np
import importlib
importlib.reload(nr)
importlib.reload(RN)

re = RN.RedeNeural( 2, [2, 1], 0.1, 2)
#re.atribuirPesos([np.array([[0.1, 0.3], [0.2, 0.4]]), np.array([[0.5], [0.6]])])
entrada = np.array([[1, 0]])

entradas = [np.array([[1, 0]]), np.array([[0, 1]]), np.array([[1, 1]]), np.array([[0, 0]])]
saida_esperada = [np.array([[1]]), np.array([[1]]), np.array([[0]]), np.array([[0]])]
saida_esperada2 = np.array([[1]])

""" #biasEntrada = [np.array([[1, 1]]), np.array([[1]])]
#biasPeso = [np.array([[0.1, 0.2]]), np.array([[0.3]])]
#re.atribuirBiasParaCadaNeuronio(biasEntrada)
#re.atribuirPesosBias(biasPeso)
re.atribuirEntradas(entrada)

print("Bias para cada neurônio:", re.biasParaCadaNeuronio)
print("Pesos Bias:", re.pesosBias)
print("Pesos iniciais:", re.pesos)

#print(re.somatorio(entrada=entrada))
#print(re.aplicarFuncaoAtivacao(re.somatorio(entrada=entrada)))
re.resultado()

#saida_esperada = np.array([[1]])
#re.erroCamadaSaida(saida_esperada)
re.erroPorCamada( saida_esperada2)
# cada entrada entradada diferente esta na coluna diferente
print("Entradas finais:", re.entradas)
# o peso de conexão com a camada n esta na posição n-1 da lista pesos
# o peso de entrada de cada neurônio da camada n está na coluna correspondente do array pesos[n]
print("Pesos finais:", re.pesos)
# o resultado de cada camada está na posição correspondente da lista resultadosPorCamada
# o resultado de cada neurônio da camada n está na linha correspondente do array resultadosPorCamada[n]
print("Resultados por camada finais:", re.resultadosPorCamada)
# a saida de cada neurônio da camada de saída está na linha correspondente do array saidas
print("Saidas finais:", re.saidas)
# o erro de cada camada está na posição correspondente da lista erros
# o erro de cada neurônio da camada n está na linha correspondente do array erros[n]
print("Erros finais:", re.erros)


print(f'Erro {re.pesosBias}')

re.ajustarPesos() 

print("Pesos ajustados finais:", re.pesos)
print("Saida esperada:", saida_esperada)"""

re.treinar(entradas, saida_esperada, 10000)
print("Resultados por camada após treinamento:", re.resultadosPorCamada)

print(re.prever(entradas=[np.array([[1, 0]]), np.array([[0, 1]]), np.array([[1, 1]]), np.array([[0, 0]])]))
# Out:
# EPOCA 1
# EPOCA 2
# EPOCA 3
# EPOCA 4
# EPOCA 5
# EPOCA 6
# EPOCA 7
# EPOCA 8
# EPOCA 9
# EPOCA 10
# EPOCA 11
# EPOCA 12
# EPOCA 13
# EPOCA 14
# EPOCA 15
# EPOCA 16
# EPOCA 17
# EPOCA 18
# EPOCA 19
# EPOCA 20
# EPOCA 21
# EPOCA 22
# EPOCA 23
# EPOCA 24
# EPOCA 25
# EPOCA 26
# EPOCA 27
# EPOCA 28
# EPOCA 29
# EPOCA 30
# EPOCA 31
# EPOCA 32
# EPOCA 33
# EPOCA 34
# EPOCA 35
# EPOCA 36
# EPOCA 37
# EPOCA 38
# EPOCA 39
# EPOCA 40
# EPOCA 41
# EPOCA 42
# EPOCA 43
# EPOCA 44
# EPOCA 45
# EPOCA 46
# EPOCA 47
# EPOCA 48
# EPOCA 49
# EPOCA 50
# EPOCA 51
# EPOCA 52
# EPOCA 53
# EPOCA 54
# EPOCA 55
# EPOCA 56
# EPOCA 57
# EPOCA 58
# EPOCA 59
# EPOCA 60
# EPOCA 61
# EPOCA 62
# EPOCA 63
# EPOCA 64
# EPOCA 65
# EPOCA 66
# EPOCA 67
# EPOCA 68
# EPOCA 69
# EPOCA 70
# EPOCA 71
# EPOCA 72
# EPOCA 73
# EPOCA 74
# EPOCA 75
# EPOCA 76
# EPOCA 77
# EPOCA 78
# EPOCA 79
# EPOCA 80
# EPOCA 81
# EPOCA 82
# EPOCA 83
# EPOCA 84
# EPOCA 85
# EPOCA 86
# EPOCA 87
# EPOCA 88
# EPOCA 89
# EPOCA 90
# EPOCA 91
# ...

# %%
import Neuronio as nr
import RedeNeural as RN
import numpy as np
import importlib
importlib.reload(nr)
importlib.reload(RN)
entradaDisplay7segmentos = [
    np.array([[1,1,1,1,1,1,0]]), #0
    np.array([[0,1,1,0,0,0,0]]), #1
    np.array([[1,1,0,1,1,0,1]]), #2
    np.array([[1,1,1,1,0,0,1]]), #3
    np.array([[0,1,1,0,0,1,1]]), #4
    np.array([[1,0,1,1,0,1,1]]), #5
    np.array([[1,0,1,1,1,1,1]]), #6
    np.array([[1,1,1,0,0,0,0]]), #7
    np.array([[1,1,1,1,1,1,1]]), #8
    np.array([[1,1,1,1,0,1,1]])  #9
]

saida_esperadaDisplay7segmentos = [
    np.array([[0, 0, 0, 0]]), #0
    np.array([[0, 0, 0, 1]]), #1
    np.array([[0, 0, 1, 0]]), #2
    np.array([[0, 0, 1, 1]]), #3
    np.array([[0, 1, 0, 0]]), #4
    np.array([[0, 1, 0, 1]]), #5
    np.array([[0, 1, 1, 0]]), #6
    np.array([[0, 1, 1, 1]]), #7
    np.array([[1, 0, 0, 0]]), #8
    np.array([[1, 0, 0, 1]])  #9
]

reDisplay7segmentos = RN.RedeNeural(2, [5, 4], 0.1, 7)

reDisplay7segmentos.treinar(entradaDisplay7segmentos, saida_esperadaDisplay7segmentos, 5000)

print(reDisplay7segmentos.prever(entradaDisplay7segmentos))
# Out:
# EPOCA 1
# EPOCA 2
# EPOCA 3
# EPOCA 4
# EPOCA 5
# EPOCA 6
# EPOCA 7
# EPOCA 8
# EPOCA 9
# EPOCA 10
# EPOCA 11
# EPOCA 12
# EPOCA 13
# EPOCA 14
# EPOCA 15
# EPOCA 16
# EPOCA 17
# EPOCA 18
# EPOCA 19
# EPOCA 20
# EPOCA 21
# EPOCA 22
# EPOCA 23
# EPOCA 24
# EPOCA 25
# EPOCA 26
# EPOCA 27
# EPOCA 28
# EPOCA 29
# EPOCA 30
# EPOCA 31
# EPOCA 32
# EPOCA 33
# EPOCA 34
# EPOCA 35
# EPOCA 36
# EPOCA 37
# EPOCA 38
# EPOCA 39
# EPOCA 40
# EPOCA 41
# EPOCA 42
# EPOCA 43
# EPOCA 44
# EPOCA 45
# EPOCA 46
# EPOCA 47
# EPOCA 48
# EPOCA 49
# EPOCA 50
# EPOCA 51
# EPOCA 52
# EPOCA 53
# EPOCA 54
# EPOCA 55
# EPOCA 56
# EPOCA 57
# EPOCA 58
# EPOCA 59
# EPOCA 60
# EPOCA 61
# EPOCA 62
# EPOCA 63
# EPOCA 64
# EPOCA 65
# EPOCA 66
# EPOCA 67
# EPOCA 68
# EPOCA 69
# EPOCA 70
# EPOCA 71
# EPOCA 72
# EPOCA 73
# EPOCA 74
# EPOCA 75
# EPOCA 76
# EPOCA 77
# EPOCA 78
# EPOCA 79
# EPOCA 80
# EPOCA 81
# EPOCA 82
# EPOCA 83
# EPOCA 84
# EPOCA 85
# EPOCA 86
# EPOCA 87
# EPOCA 88
# EPOCA 89
# EPOCA 90
# EPOCA 91
# ...
